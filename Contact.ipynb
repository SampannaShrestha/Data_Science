# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt #plotting
import seaborn as sns #graphical representation

# %%
df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#               Unnamed: 0     Contact                Email Business Type  \
# 0              KUNAL ROY  9827328551  Yorkunal4@gmail.com           NaN
# 1           Ojha Kshitiz  9848617751                  NaN   Mobile shop
# 2       Santosh Upadhyay  9856037823                  NaN       General
# 3         Pradeep Dhakal  9841581150                  NaN    Montessori
# 4  Suresh Sudik Garagain  9840015215                  NaN           NaN
#
#    Budget  Starting Date  End Date                             Response  RM
# 0     NaN            NaN       NaN                                  NaN NaN
# 1     NaN            NaN       NaN        not interested in advertising NaN
# 2     NaN            NaN       NaN                must contact in viber NaN
# 3     NaN            NaN       NaN      want to start the advertisement NaN
# 4     NaN            NaN       NaN  number not available 9th april 3:00 NaN

# %%
df.drop(['Budget', 'Starting Date', 'End Date','RM','Email'], axis=1, inplace=True)

# %%
df
# Out:
#                                            Unnamed: 0                 Contact  \
# 0                                           KUNAL ROY              9827328551
# 1                                        Ojha Kshitiz              9848617751
# 2                                    Santosh Upadhyay              9856037823
# 3                                      Pradeep Dhakal              9841581150
# 4                               Suresh Sudik Garagain              9840015215
# 5                              Bibhash Ambrose Mallik              9817849121
# 6                                               Vivek              9857030993
# 7                                           BP subedi              9841825504
# 8                                  Sabin Chamling Ssg              9813889611
# 9                                         Deepak Shah              9815225450
# 10                                        Rk Shrestha              9841281841
# ...

# %%
df['Contact'].describe()
# Out:
# count            501
# unique           477
# top       9854028398
# freq               3
# Name: Contact, dtype: object

# %%
df.aggregate('mean')
# Out:
# Series([], dtype: float64)

# %%
df
# Out:
#                                            Unnamed: 0                 Contact  \
# 0                                           KUNAL ROY              9827328551
# 1                                        Ojha Kshitiz              9848617751
# 2                                    Santosh Upadhyay              9856037823
# 3                                      Pradeep Dhakal              9841581150
# 4                               Suresh Sudik Garagain              9840015215
# 5                              Bibhash Ambrose Mallik              9817849121
# 6                                               Vivek              9857030993
# 7                                           BP subedi              9841825504
# 8                                  Sabin Chamling Ssg              9813889611
# 9                                         Deepak Shah              9815225450
# 10                                        Rk Shrestha              9841281841
# ...

# %%
number=df['Contact']
ntcNumberUsers = []
ntcPattern=re.compile('98[4-6][0-9]{7}');
x=ntcPattern.match(number[1])
# print(type(x))
for i in range(0, number.size-1):
    if isinstance(number[i], str):
        result = ntcPattern.match(number[i])
        if result:
            ntcNumberUsers.append(number[i])
print(ntcNumberUsers)
# Out:
# ['9848617751', '9856037823', '9841581150', '9840015215', '9857030993', '9841825504', '9841281841', '9851208011', '9851933395', '9849339439', '9860466387', '9841248997', '9857050910', '9849601143', '9851075468', '9843934365', '9851162086', '9849470659', '9851192499', '9841320766', '9867424709', '9862689249', '9845248672', '9860333198', '9857024717', '9851134620', '9849717982', '9857036752', '9851192614', '9856078100', '9855063855', '9864455516', '9867003304', '9841941007', '9849680813', '9841009879', '9851226464', '9860200278', '9851120796', '9841409269', '9851098080/ 9861929859', '9855069215', '9843766345', '9855077321', '9842059713', '9851192612', '9852849060', '9851033010', '9851148792', '9861726497', '9842056164', '9867926884', '9843866133', '9856051606', '9858024433/9857039492', '9851076384', '9860228122', '9841409988', '9852021345', '9865237020', '9851036067', '9861288843', '9856023690/9802523690', '9843688811', '9851023285', '9856039551', '9843212406', '9851168362', '9840432076
816761489', '9805429360', '9822577006', '9800516682', '9818934022', '9808202019', '9803335455', '9805833257', '9817237825', '9824149213', '9808671751', '9816946992', '9813708149', '9802069798', '9801142224', '9808969093', '9819177656', '9813550646', '9818593195', '9808870536', '9808764879', '9801018277', '9803303262', '9802016657', '9818890373', '9810058974', '9823474650', '9811307386', '9818066404', '9825170774', '9802034080', '9807140669', '9801156565', '9823087012', '9808408611', '9817113539', '9803456726', '9814189416', '9801094800', '9814110611', '9823014684', '9801094800', '9803027890', '9804135499', '9801005300', '9824331068', '9817117593', '9818803682', '9808540732', '9802791247', '9801023327', '9817197943', '9823249898', '9816069777', '9816481887', '9813804645', '9803647605', '9823406069', '9802910012', '9801116110', '9817011456', '9813280432', '9823491268', '9807185695', '9804303621', '9808455575', '9814326597', '9812329672', '9803022100', '9816224862', '9806584195', '9807004757', '9821619343', '9813522726', '9824027576', '9804091664', '9824979190', '9815013761', '9813683838', '9823406069', '9823115305', '9801025289', '9801094800', '9805438044', '9801650075', '9808870536']

# %%
# Out:
#                                            Unnamed: 0                 Contact  \
# 0                                           KUNAL ROY              9827328551
# 1                                        Ojha Kshitiz              9848617751
# 2                                    Santosh Upadhyay              9856037823
# 3                                      Pradeep Dhakal              9841581150
# 4                               Suresh Sudik Garagain              9840015215
# 5                              Bibhash Ambrose Mallik              9817849121
# 6                                               Vivek              9857030993
# 7                                           BP subedi              9841825504
# 8                                  Sabin Chamling Ssg              9813889611
# 9                                         Deepak Shah              9815225450
# 10                                        Rk Shrestha              9841281841
# ...

# %%
df['Telecom']=df['Contact']
df.head()
# Out:
#               Unnamed: 0     Contact Business Type  \
# 0              KUNAL ROY  9827328551           NaN
# 1           Ojha Kshitiz  9848617751   Mobile shop
# 2       Santosh Upadhyay  9856037823       General
# 3         Pradeep Dhakal  9841581150    Montessori
# 4  Suresh Sudik Garagain  9840015215           NaN
#
#                               Response     Telecom
# 0                                  NaN  9827328551
# 1        not interested in advertising  9848617751
# 2                must contact in viber  9856037823
# 3      want to start the advertisement  9841581150
# 4  number not available 9th april 3:00  9840015215

# %%
for (row, col) in df.iterrows():
    if (col.Telecom) in NTC:
        df['Telecom'].replace(to_replace=col.Telecom, value='NTC', inplace=True)
    if (col.Telecom) in NCell:
        df['Telecom'].replace(to_replace=col.Telecom, value='NCell', inplace=True)

# %%
df.head()
# Out:
#               Unnamed: 0     Contact Business Type  \
# 0              KUNAL ROY  9827328551           NaN
# 1           Ojha Kshitiz  9848617751   Mobile shop
# 2       Santosh Upadhyay  9856037823       General
# 3         Pradeep Dhakal  9841581150    Montessori
# 4  Suresh Sudik Garagain  9840015215           NaN
#
#                               Response Telecom
# 0                                  NaN   NCell
# 1        not interested in advertising     NTC
# 2                must contact in viber     NTC
# 3      want to start the advertisement     NTC
# 4  number not available 9th april 3:00     NTC

# %%
df.groupby('Telecom')

# %%
Ncelldf=df[df['Telecom'] == 'NCell']
Ncelldf.head()
# Out:
#                 Unnamed: 0     Contact                        Business Type  \
# 0                KUNAL ROY  9827328551                                  NaN
# 5   Bibhash Ambrose Mallik  9817849121                                  NaN
# 8       Sabin Chamling Ssg  9813889611  photo studio & hotel (jhapa, damak)
# 9              Deepak Shah  9815225450                   Hardware suppliers
# 11         Manish Bharrari  9824047768                                  NaN
#
#                          Response Telecom
# 0                             NaN   NCell
# 5      not recieve call 9th april   NCell
# 8                   not reachable   NCell
# 9   viber all details or whatsapp   NCell
# 11                            NaN   NCell

# %%
ncellnumber = Ncelldf.to_excel (r'C:\Users\sampa\OneDrive\Desktop\Sampanna\resources\ncellnumber.xlsx', index = None, header=True) #Don't forget to add '.xlsx' at the end of the path

print (Ncelldf)
# Out:
#                    Unnamed: 0     Contact  \
# 0                   KUNAL ROY  9827328551
# 5      Bibhash Ambrose Mallik  9817849121
# 8          Sabin Chamling Ssg  9813889611
# 9                 Deepak Shah  9815225450
# 11            Manish Bharrari  9824047768
# 20             Horizen Prince  9818823499
# 31              Utsav Bastola  9806084570
# 35     Manandhar Pathak Luxmi  9823124428
# 38                 Atit Magar  9803214417
# 40         Ashok Tamang theng  9808316261
# 48                     OTs PL  9823111400
# 52                Miwang Dong  9818022176
# 53         Anup Lingden Limbu  9813578641
# 55     Luxmi Pathak Manandhar  9823124428
# 56             Proobeen Kumar  9811768300
# 57        Street aryan kausal  9819535180
# 59           Ram baral Mandal  9801130517
# 66           Bikash prajapati  9818286993
# 67            Dhirendra Gupta  9816330452
# 69         Anwarul hak Ansari  9811857865
# 71              Deepesh Shahi  9818120465
# ...

# %%
ntcnumberdf=df[df['Telecom'] == 'NTC']
ntcnumberdf.head()
# Out:
#               Unnamed: 0     Contact Business Type  \
# 1           Ojha Kshitiz  9848617751   Mobile shop
# 2       Santosh Upadhyay  9856037823       General
# 3         Pradeep Dhakal  9841581150    Montessori
# 4  Suresh Sudik Garagain  9840015215           NaN
# 6                  Vivek  9857030993           NaN
#
#                               Response Telecom
# 1        not interested in advertising     NTC
# 2                must contact in viber     NTC
# 3      want to start the advertisement     NTC
# 4  number not available 9th april 3:00     NTC
# 6           not recieve call 9th april     NTC

# %%
ntcnumber = ntcnumberdf.to_excel (r'C:\Users\sampa\OneDrive\Desktop\Sampanna\resources\ntcnumber.xlsx', index = None, header=True) #Don't forget to add '.xlsx' at the end of the path

print (ntcnumberdf)
# Out:
#                                            Unnamed: 0     Contact  \
# 1                                        Ojha Kshitiz  9848617751
# 2                                    Santosh Upadhyay  9856037823
# 3                                      Pradeep Dhakal  9841581150
# 4                               Suresh Sudik Garagain  9840015215
# 6                                               Vivek  9857030993
# 7                                           BP subedi  9841825504
# 10                                        Rk Shrestha  9841281841
# 12                                       Chesang Lama  9851208011
# 13                                Shree Krishna Rijal  9851933395
# 14                       J.D. corier and cargo srvice  9849339439
# 15                                   Sagar Raj Khadka  9860466387
# 16                                  Saurab Raj Sharma  9841248997
# 17                                  Sarada Dana Udyog  9857050910
# ...
